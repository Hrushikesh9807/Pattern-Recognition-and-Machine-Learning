# %%
from sklearn import svm
import pandas as pd    
import numpy as np
from sklearn.metrics import accuracy_score

# %%
# Hrushikesh
dtrain = pd.read_csv(r"H:\Sem-7\CS5691\Assignment-4\Dataset2\train.csv")
dtest = pd.read_csv(r"H:\Sem-7\CS5691\Assignment-4\Dataset2\test.csv")
dval = pd.read_csv(r"H:\Sem-7\CS5691\Assignment-4\Dataset2\val.csv")

# %%
xtrain = dtrain.drop(columns=['label']).to_numpy()
ytrain = dtrain['label'].to_numpy()

xtest = dtest.drop(columns=['label']).to_numpy()
ytest = dtest['label'].to_numpy()

xval = dval.drop(columns=['label']).to_numpy()
yval = dval['label'].to_numpy()

# %% [markdown]
# # Polynomial Kernel

# %%
from sklearn import svm

deg = 3
clf = svm.SVC(kernel='poly', degree=deg, C=1)
clf.fit(xtrain, ytrain)
print(f"Poly kernel, C=1, deg={deg}")

ytest_pred = clf.predict(xtest)
ytrain_pred = clf.predict(xtrain)
yval_pred = clf.predict(xval)

print("Train Accuracy: ",  accuracy_score(ytrain_pred, ytrain))

print("Test Accuracy: ",  accuracy_score(ytest_pred, ytest))

print("Validation accuracy: ", accuracy_score(yval_pred, yval))
# Out:
# Poly kernel, C=1, deg=3
# Train Accuracy:  0.755120213713268
# Test Accuracy:  0.725
# Validation accuracy:  0.7823343848580442

# %%
from sklearn import svm

for c in [1, 10, 100]:
    for deg in [3, 5, 7, 9, 11, 13, 17, 19]:
        clf = svm.SVC(kernel='poly', degree=deg, C=c)
        clf.fit(xtrain, ytrain)
        print(f"Poly kernel, C={c}, deg={deg}")

        ytest_pred = clf.predict(xtest)
        ytrain_pred = clf.predict(xtrain)
        yval_pred = clf.predict(xval)

        print("Train Accuracy: ",  accuracy_score(ytrain_pred, ytrain))

        print("Test Accuracy: ",  accuracy_score(ytest_pred, ytest))

        print("Validation accuracy: ", accuracy_score(yval_pred, yval))
        print("")
# Out:
# Poly kernel, C=1, deg=3
# Train Accuracy:  0.755120213713268
# Test Accuracy:  0.725
# Validation accuracy:  0.7823343848580442
#
# Poly kernel, C=1, deg=5
# Train Accuracy:  0.7916295636687445
# Test Accuracy:  0.7625
# Validation accuracy:  0.7981072555205048
#
# Poly kernel, C=1, deg=7
# Train Accuracy:  0.8227960819234195
# Test Accuracy:  0.79375
# Validation accuracy:  0.8264984227129337
#
# Poly kernel, C=1, deg=9
# Train Accuracy:  0.8406055209260909
# Test Accuracy:  0.8
# Validation accuracy:  0.8517350157728707
#
# Poly kernel, C=1, deg=11
# Train Accuracy:  0.8441674087266251
# Test Accuracy:  0.8125
# Validation accuracy:  0.8422712933753943
#
# Poly kernel, C=1, deg=13
# Train Accuracy:  0.8459483526268923
# Test Accuracy:  0.80625
# Validation accuracy:  0.8485804416403786
#
# Poly kernel, C=1, deg=17
# Train Accuracy:  0.8290293855743545
# Test Accuracy:  0.7875
# Validation accuracy:  0.832807570977918
#
# Poly kernel, C=1, deg=19
# ...

# %% [markdown]
# ### Result
# | Kernel | C  | Degree | Train Accuracy | Test Accuracy | Validation Accuracy |
# |---------|----|---------|----------------|----------------|----------------------|
# | Poly | 1 | 3  | 0.7551 | 0.7250 | 0.7823 |
# | Poly | 1 | 5  | 0.7916 | 0.7625 | 0.7981 |
# | Poly | 1 | 7  | 0.8228 | 0.7938 | 0.8265 |
# | Poly | 1 | 9  | 0.8406 | 0.8000 | 0.8517 |
# | Poly | 1 | 11 | 0.8442 | 0.8125 | 0.8423 |
# | Poly | 1 | 13 | 0.8459 | 0.8063 | 0.8486 |
# | Poly | 1 | 17 | 0.8290 | 0.7875 | 0.8328 |
# | Poly | 1 | 19 | 0.8210 | 0.7750 | 0.8233 |
# | Poly | 10 | 3  | 0.7524 | 0.7250 | 0.7792 |
# | Poly | 10 | 5  | 0.7827 | 0.7625 | 0.7918 |
# | Poly | 10 | 7  | 0.8130 | 0.7875 | 0.8233 |
# | Poly | 10 | 9  | 0.8486 | 0.8063 | 0.8517 |
# | Poly | 10 | 11 | 0.8468 | 0.8125 | 0.8486 |
# | Poly | 10 | 13 | 0.8531 | 0.8125 | 0.8517 |
# | Poly | 10 | 17 | 0.8424 | 0.8125 | 0.8423 |
# | Poly | 10 | 19 | 0.8353 | 0.7938 | 0.8328 |
# | Poly | 100 | 3  | 0.7524 | 0.7250 | 0.7792 |
# | Poly | 100 | 5  | 0.7943 | 0.7563 | 0.7918 |
# | Poly | 100 | 7  | 0.8335 | 0.7938 | 0.8454 |
# | Poly | 100 | 9  | 0.8486 | 0.8250 | 0.8517 |
# | Poly | 100 | 11 | 0.8584 | 0.8125 | 0.8612 |
# | Poly | 100 | 13 | 0.8513 | 0.8063 | 0.8580 |
# | Poly | 100 | 17 | 0.8495 | 0.8125 | 0.8454 |
# | Poly | 100 | 19 | 0.8459 | 0.8063 | 0.8391 |
#
# The best model is degree 13 and c 100.

# %%
clf = svm.SVC(kernel='poly', degree=13, C=100)
clf.fit(xtrain, ytrain)
print(f"Poly kernel, C={c}, deg={deg}")

ytest_pred = clf.predict(xtest)
ytrain_pred = clf.predict(xtrain)
yval_pred = clf.predict(xval)

print("Train Accuracy: ",  accuracy_score(ytrain_pred, ytrain))

print("Test Accuracy: ",  accuracy_score(ytest_pred, ytest))

print("Validation accuracy: ", accuracy_score(yval_pred, yval))
print("")
# Out:
# Poly kernel, C=100, deg=19
# Train Accuracy:  0.8512911843276937
# Test Accuracy:  0.80625
# Validation accuracy:  0.8580441640378549

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm_train = confusion_matrix(ytrain, ytrain_pred)
cm_test = confusion_matrix(ytest, ytest_pred)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

ConfusionMatrixDisplay(cm_train).plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title('Train Confusion Matrix')

ConfusionMatrixDisplay(cm_test).plot(ax=axes[1], cmap='Oranges', colorbar=False)
axes[1].set_title('Test Confusion Matrix')

plt.tight_layout()
plt.show()

# %%
def plot_decision_regions(clf, X, y, title="Decision Region (Train)"):
    # mesh
    pad = 1.0
    x_min, x_max = X[:, 0].min() - pad, X[:, 0].max() + pad
    y_min, y_max = X[:, 1].min() - pad, X[:, 1].max() + pad
    xx, yy = np.meshgrid(
        np.linspace(x_min, x_max, 400),
        np.linspace(y_min, y_max, 400)
    )

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

    # decision regions
    plt.contourf(xx, yy, Z, alpha=0.3)

    # training points
    plt.scatter(X[:, 0], X[:, 1], c=y, s=35, edgecolors='k')

    # support vectors (works for SVC)
    if hasattr(clf, "support_vectors_"):
        sv = clf.support_vectors_
        plt.scatter(sv[:, 0], sv[:, 1],
                    s=120, facecolors='none', edgecolors='k', linewidths=1.5,
                    label="Support Vectors")
        plt.legend()

    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
plot_decision_regions(clf, xtrain, ytrain, title="Decision Region (Train Data)")

# %%
plot_decision_regions(clf, xtest, ytest, title="Decision Region (Test Data)")

# %% [markdown]
# # Gaussian kernel

# %%
from sklearn import svm

gs = [0.001, 0.01, 0.1, 1, 10, 100]

for c in [1, 10, 100]:
    for g in gs:
        clf = svm.SVC(kernel='rbf', C=c, gamma=g)
        clf.fit(xtrain, ytrain)
        print(f"Gaussian kernel, C={c}, width={g}")

        ytest_pred = clf.predict(xtest)
        ytrain_pred = clf.predict(xtrain)
        yval_pred = clf.predict(xval)

        print("Train Accuracy: ",  accuracy_score(ytrain_pred, ytrain))

        print("Test Accuracy: ",  accuracy_score(ytest_pred, ytest))

        print("Validation accuracy: ", accuracy_score(yval_pred, yval))
        print("")
# Out:
# Gaussian kernel, C=1, width=0.001
# Train Accuracy:  0.7898486197684773
# Test Accuracy:  0.74375
# Validation accuracy:  0.804416403785489
#
# Gaussian kernel, C=1, width=0.01
# Train Accuracy:  0.9795191451469278
# Test Accuracy:  0.95
# Validation accuracy:  0.9873817034700315
#
# Gaussian kernel, C=1, width=0.1
# Train Accuracy:  0.9902048085485308
# Test Accuracy:  0.96875
# Validation accuracy:  0.9905362776025236
#
# Gaussian kernel, C=1, width=1
# Train Accuracy:  0.9928762243989314
# Test Accuracy:  0.96875
# Validation accuracy:  0.9905362776025236
#
# Gaussian kernel, C=1, width=10
# Train Accuracy:  0.9991095280498664
# Test Accuracy:  0.9375
# Validation accuracy:  0.9305993690851735
#
# Gaussian kernel, C=1, width=100
# Train Accuracy:  1.0
# Test Accuracy:  0.58125
# Validation accuracy:  0.5867507886435331
#
# Gaussian kernel, C=10, width=0.001
# Train Accuracy:  0.918967052537845
# Test Accuracy:  0.9
# Validation accuracy:  0.9274447949526814
#
# ...

# %% [markdown]
# ### Result
# | **C** | **Width** | **Train Accuracy** | **Test Accuracy** | **Validation Accuracy** |
# |:------:|:----------:|:------------------:|:-----------------:|:-----------------------:|
# | 1 | 0.001 | 0.7898 | 0.7438 | 0.8044 |
# | 1 | 0.01 | 0.9795 | 0.9500 | 0.9874 |
# | 1 | 0.1 | 0.9902 | 0.9688 | 0.9905 |
# | 1 | 1 | 0.9929 | 0.9688 | 0.9905 |
# | 1 | 10 | 0.9991 | 0.9375 | 0.9306 |
# | 1 | 100 | 1.0000 | 0.5813 | 0.5868 |
# | 10 | 0.001 | 0.9190 | 0.9000 | 0.9274 |
# | 10 | 0.01 | 0.9831 | 0.9688 | 0.9905 |
# | 10 | 0.1 | 0.9902 | 0.9688 | 0.9842 |
# | 10 | 1 | 0.9955 | 0.9688 | 0.9905 |
# | 10 | 10 | 1.0000 | 0.9375 | 0.9306 |
# | 10 | 100 | 1.0000 | 0.5938 | 0.5962 |
# | 100 | 0.001 | 0.9590 | 0.9375 | 0.9779 |
# | 100 | 0.01 | 0.9893 | 0.9688 | 0.9905 |
# | 100 | 0.1 | 0.9929 | 0.9688 | 0.9874 |
# | 100 | 1 | 0.9982 | 0.9500 | 0.9811 |
# | 100 | 10 | 1.0000 | 0.9375 | 0.9306 |
# | 100 | 100 | 1.0000 | 0.5938 | 0.5962 |
#
# the best model is c=10, width 1

# %%
clf = svm.SVC(kernel='rbf', C=10, gamma=1)
clf.fit(xtrain, ytrain)
print(f"Gaussian kernel, C={1}, width={g}")

ytest_pred = clf.predict(xtest)
ytrain_pred = clf.predict(xtrain)
yval_pred = clf.predict(xval)

print("Train Accuracy: ",  accuracy_score(ytrain_pred, ytrain))

print("Test Accuracy: ",  accuracy_score(ytest_pred, ytest))

print("Validation accuracy: ", accuracy_score(yval_pred, yval))
print("")
# Out:
# Gaussian kernel, C=1, width=100
# Train Accuracy:  0.9955476402493322
# Test Accuracy:  0.96875
# Validation accuracy:  0.9905362776025236

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm_train = confusion_matrix(ytrain, ytrain_pred)
cm_test = confusion_matrix(ytest, ytest_pred)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

ConfusionMatrixDisplay(cm_train).plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title('Train Confusion Matrix')

ConfusionMatrixDisplay(cm_test).plot(ax=axes[1], cmap='Oranges', colorbar=False)
axes[1].set_title('Test Confusion Matrix')

plt.tight_layout()
plt.show()

# %%
plot_decision_regions(clf, xtrain, ytrain, title="Decision Region (Train Data)")

# %%
plot_decision_regions(clf, xtest, ytest, title="Decision Region (Train Data)")
